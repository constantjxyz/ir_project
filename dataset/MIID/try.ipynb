# %%
import os 
import numpy as np
import pandas as pd
import json
import string

# %% [markdown]
# # Preprocess

# %%
ori = np.load('original_data.npz', allow_pickle=True)
print(ori.files)
mention_labels = ori['mention_labels']
mention_names = ori['mention_names']
# Out:
# ['mention_indices', 'mention_labels', 'mention_names', 'concept_names', 'concept_indices']

# %%
relation_file ='../iBKH/Di_Di_res.csv'
relation = pd.read_csv(relation_file)
relation
# Out:
#           Disease_1   Disease_2  is_a  Resemble    Source
# 0      DOID:0001816    DOID:175     1         0        DO
# 1          DOID:175    DOID:176     1         0        DO
# 2      DOID:0002116  DOID:10124     1         0        DO
# 3        DOID:10124   DOID:5614     1         0        DO
# 4      DOID:0014667      DOID:4     1         0        DO
# ...             ...         ...   ...       ...       ...
# 11067      DOID:219   DOID:8577     0         1  Hetionet
# 11068     DOID:2994  DOID:13499     0         1  Hetionet
# 11069     DOID:1793  DOID:10534     0         1  Hetionet
# 11070      DOID:219   DOID:3121     0         1  Hetionet
# 11071     DOID:4045   DOID:2174     0         1  Hetionet
#
# [11072 rows x 5 columns]

# %%
entity = pd.read_csv('../iBKH/disease_vocab.csv', dtype=str)
entity['name'] = entity['name'].astype(str).apply(str.lower).apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
entity
# Out:
#                primary                  name         do_id kegg_id  \
# 0               DOID:4               disease        DOID:4     NaN
# 1         DOID:0001816          angiosarcoma  DOID:0001816  H01557
# 2             DOID:175       vascular cancer      DOID:175     NaN
# 3         DOID:0002116             pterygium  DOID:0002116     NaN
# 4           DOID:10124       corneal disease    DOID:10124     NaN
# ...                ...                   ...           ...     ...
# 19231  iDISK:DC0492572     bleeding tendency           NaN     NaN
# 19232  iDISK:DC0492815          skin abscess           NaN     NaN
# 19233  iDISK:DC0493114    cystitis recurrent           NaN     NaN
# 19234  iDISK:DC0493119               epstein           NaN     NaN
# 19235  iDISK:DC0493235  deterioration mental           NaN     NaN
#
#        pharmgkb_id  mesh_id  umls_cui icd_10  icd_9 omim_id   iDISK_id
# 0              NaN  D004194  C0012634    NaN    NaN     NaN  DC0478447
# 1         PA444390  D006394  C0018923    NaN    NaN     NaN        NaN
# 2              NaN  D019043  C0282607    NaN    NaN     NaN        NaN
# 3              NaN      NaN  C0033999    NaN    NaN     NaN        NaN
# 4      PA165108965  D003316  C0010034  H18.9  371.9     NaN        NaN
# ...            ...      ...       ...    ...    ...     ...        ...
# 19231          NaN      NaN  C1458140    NaN    NaN     NaN  DC0492572
# 19232          NaN      NaN  C0149777    NaN    NaN     NaN  DC0492815
# 19233          NaN      NaN  C0581366    NaN    NaN     NaN  DC0493114
# 19234          NaN      NaN  C1396851    NaN    NaN     NaN  DC0493119
# 19235          NaN      NaN  C0234985    NaN    NaN     NaN  DC0493235
#
# [19236 rows x 11 columns]

# %% [markdown]
# # Get related entities

# %%
def get_doid(concept, df_entity):
    query = df_entity[df_entity['name'] == concept] 
    # print(query)
    # assert len(query) == 1
    doid = query['primary'].iloc[0]
    return doid

# %%
def get_name(doid, df_entity):
    query = df_entity[df_entity['primary'] == doid] 
    # print(query)
    # assert len(query) == 1
    name = query['name'].iloc[0]
    return name

# %%
def get_related_disease_items(label, df_entity, df_relation):
    related_entities = set()
    label_doid = get_doid(label, df_entity)
    # print(label_doid)
    # search for 1-hop items when label is in "Disease_1"
    match_1 = df_relation['Disease_1'].isin([label_doid])
    searched_doid = list(df_relation[match_1]['Disease_2'])
    for doid in searched_doid:
        name = get_name(doid, df_entity) 
        if name not in related_entities:
            related_entities.add(name)
    # search for 1-hop items when label is in "Disease_2"
    match_2 = df_relation['Disease_2'].isin([label_doid])
    searched_doid = list(df_relation[match_2]['Disease_1'])
    for doid in searched_doid:
        name = get_name(doid, df_entity) 
        if name not in related_entities:
            related_entities.add(name)
    return related_entities
get_related_disease_items('tuberculous pneumothorax', entity,relation)
# Out:
# {'pneumothorax'}

# %%
# relevance = pd.DataFrame(columns=['mention_names', 'relevance_0', 'relevance_1', 'relevance_2'])
# for i in range(len(mention_labels[:10])):
#     mention_name = mention_names[i]
#     mention_label = mention_labels[i]
#     zero_hop_set = {mention_label}
#     one_hop_set = get_related_disease_items(mention_label, entity, relation)   # get a set
#     two_hop_set = set()
#     for item in one_hop_set:
#         # print(item)
#         temp_two_hop_set = get_related_disease_items(item, entity, relation)
#         two_hop_set = two_hop_set | temp_two_hop_set
#     two_hop_set = two_hop_set - one_hop_set - zero_hop_set
#     print(mention_name)
#     print(zero_hop_set)
#     print(one_hop_set)
#     print(two_hop_set)
#     relevance.loc[len(relevance)] = [mention_name, zero_hop_set, one_hop_set, two_hop_set]
# Out:
# tuberculous pneumothorax unspecified
# {'tuberculous pneumothorax'}
# {'pneumothorax'}
# {'spontaneous tension pneumothorax', 'pleural disease', 'primary spontaneous pneumothorax', 'hemopneumothorax'}
# pulmonary tuberculosis unspecified unspecified
# {'pulmonary tuberculosis'}
# {'tuberculosis'}
# {'ocular tuberculosis', 'cardiac tuberculosis', 'multidrugresistant tuberculosis', 'extrapulmonary tuberculosis', 'primary bacterial infectious disease'}
# tuberculous pleurisy unspecified
# {'pleural tuberculosis'}
# {'extrapulmonary tuberculosis'}
# {'central nervous system tuberculosis', 'tuberculosis', 'lymph node tuberculosis', 'skeletal tuberculosis', 'miliary tuberculosis', 'pericardial tuberculosis', 'abdominal tuberculosis', 'urogenital tuberculosis'}
# tuberculous meningitis unspecified
# {'tuberculous meningitis nos'}
# set()
# set()
# cholera due to vibrio cholerae
# {'cholera'}
# {'primary bacterial infectious disease'}
# {'rhinoscleroma', 'relapsing fever', 'gonorrhea', 'bejel', 'granuloma inguinale', 'tetanus', 'staphyloenterotoxemia', 'melioidosis', 'sennetsu fever', 'tularemia', 'diphtheria', 'typhoid fever', 'tuberculosis', 'glanders', 'salmonellosis', 'plague', 'paratyphoid fever', 'leprosy', 'lyme disease', 'bartonellosis', 'q fever', 'ornithosis', 'chancroid', 'botulism', 'buruli ulcer disease', 'listeriosis', 'shigellosis', 'ehrlichiosis', 'haverhill fever', 'mycobacterium avium complex disease', 'legionellosis', 'anthrax disease', 'yaws', 'spotted fever', 'sodoku disease', 'syphilis', 'erysipeloid', 'bacterial infectious disease', 'typhus', 'leptospirosis', 'pinta disease', 'pasteurellosis', 'brucellosis'}
# cholera unspecified
# {'cholera'}
# {'primary bacterial infectious disease'}
# {'rhinoscleroma', 'relapsing fever', 'gonorrhea', 'bejel', 'granuloma inguinale', 'tetanus', 'staphyloenterotoxemia', 'melioidosis', 'sennetsu fever', 'tularemia', 'diphtheria', 'typhoid fever', 'tuberculosis', 'glanders', 'salmonellosis', 'plague', 'paratyphoid fever', 'leprosy', 'lyme disease', 'bartonellosis', 'q fever', 'ornithosis', 'chancroid', 'botulism', 'buruli ulcer disease', 'listeriosis', 'shigellosis', 'ehrlichiosis', 'haverhill fever', 'mycobacterium avium complex disease', 'legionellosis', 'anthrax disease', 'yaws', 'spotted fever', 'sodoku disease', 'syphilis', 'erysipeloid', 'bacterial infectious disease', 'typhus', 'leptospirosis', 'pinta disease', 'pasteurellosis', 'brucellosis'}
# paratyphoid fever unspecified
# {'paratyphoid fever'}
# {'primary bacterial infectious disease'}
# {'rhinoscleroma', 'relapsing fever', 'gonorrhea', 'bejel', 'granuloma inguinale', 'tetanus', 'staphyloenterotoxemia', 'melioidosis', 'sennetsu fever', 'tularemia', 'diphtheria', 'typhoid fever', 'tuberculosis', 'cholera', 'glanders', 'salmonellosis', 'plague', 'leprosy', 'lyme disease', 'bartonellosis', 'q fever', 'ornithosis', 'chancroid', 'botulism', 'buruli ulcer disease', 'listeriosis', 'shigellosis', 'ehrlichiosis', 'haverhill fever', 'mycobacterium avium complex disease', 'legionellosis', 'anthrax disease', 'yaws', 'spotted fever', 'sodoku disease', 'syphilis', 'erysipeloid', 'bacterial infectious disease', 'typhus', 'leptospirosis', 'pinta disease', 'pasteurellosis', 'brucellosis'}
# salmonella infection unspecified
# {'salmonella infections'}
# set()
# set()
# shigellosis unspecified
# {'shigellosis'}
# {'primary bacterial infectious disease'}
# {'rhinoscleroma', 'relapsing fever', 'gonorrhea', 'bejel', 'granuloma inguinale', 'tetanus', 'staphyloenterotoxemia', 'melioidosis', 'sennetsu fever', 'tularemia', 'diphtheria', 'typhoid fever', 'tuberculosis', 'cholera', 'glanders', 'salmonellosis', 'plague', 'paratyphoid fever', 'leprosy', 'lyme disease', 'bartonellosis', 'q fever', 'ornithosis', 'chancroid', 'botulism', 'buruli ulcer disease', 'listeriosis', 'ehrlichiosis', 'haverhill fever', 'mycobacterium avium complex disease', 'legionellosis', 'anthrax disease', 'yaws', 'spotted fever', 'sodoku disease', 'syphilis', 'erysipeloid', 'bacterial infectious disease', 'typhus', 'leptospirosis', 'pinta disease', 'pasteurellosis', 'brucellosis'}
# staphylococcal food poisoning
# {'staphyloenterotoxemia'}
# {'primary bacterial infectious disease'}
# {'rhinoscleroma', 'relapsing fever', 'gonorrhea', 'bejel', 'granuloma inguinale', 'tetanus', 'melioidosis', 'sennetsu fever', 'tularemia', 'diphtheria', 'typhoid fever', 'tuberculosis', 'cholera', 'glanders', 'salmonellosis', 'plague', 'paratyphoid fever', 'leprosy', 'lyme disease', 'bartonellosis', 'q fever', 'ornithosis', 'chancroid', 'botulism', 'buruli ulcer disease', 'listeriosis', 'shigellosis', 'ehrlichiosis', 'haverhill fever', 'mycobacterium avium complex disease', 'legionellosis', 'anthrax disease', 'yaws', 'spotted fever', 'sodoku disease', 'syphilis', 'erysipeloid', 'bacterial infectious disease', 'typhus', 'leptospirosis', 'pinta disease', 'pasteurellosis', 'brucellosis'}

# %%
all_dict = dict()
for i in range(len(mention_labels)):
    print(f'Start index {i}, total length {len(mention_labels)}')
    mention_name = mention_names[i]
    mention_label = mention_labels[i]
    zero_hop_set = {mention_label}
    one_hop_set = get_related_disease_items(mention_label, entity, relation)   # get a set
    two_hop_set = set()
    for item in one_hop_set:
        # print(item)
        temp_two_hop_set = get_related_disease_items(item, entity, relation)
        two_hop_set = two_hop_set | temp_two_hop_set
    two_hop_set = two_hop_set - one_hop_set - zero_hop_set
    # print(mention_name)
    # print(zero_hop_set)
    # print(one_hop_set)
    # print(two_hop_set)
    all_dict[i] = {'mention_name':mention_name, 'zero_hop_list': list(zero_hop_set), 'one_hop_list': list(one_hop_set), 'two_hop_list': list(two_hop_set)}
# Out:
# Start index 0, total length 1493
# Start index 1, total length 1493
# Start index 2, total length 1493
# Start index 3, total length 1493
# Start index 4, total length 1493
# Start index 5, total length 1493
# Start index 6, total length 1493
# Start index 7, total length 1493
# Start index 8, total length 1493
# Start index 9, total length 1493
# Start index 10, total length 1493
# Start index 11, total length 1493
# Start index 12, total length 1493
# Start index 13, total length 1493
# Start index 14, total length 1493
# Start index 15, total length 1493
# Start index 16, total length 1493
# Start index 17, total length 1493
# Start index 18, total length 1493
# Start index 19, total length 1493
# Start index 20, total length 1493
# Start index 21, total length 1493
# Start index 22, total length 1493
# Start index 23, total length 1493
# Start index 24, total length 1493
# Start index 25, total length 1493
# Start index 26, total length 1493
# Start index 27, total length 1493
# Start index 28, total length 1493
# Start index 29, total length 1493
# Start index 30, total length 1493
# Start index 31, total length 1493
# Start index 32, total length 1493
# Start index 33, total length 1493
# Start index 34, total length 1493
# Start index 35, total length 1493
# Start index 36, total length 1493
# Start index 37, total length 1493
# Start index 38, total length 1493
# Start index 39, total length 1493
# Start index 40, total length 1493
# Start index 41, total length 1493
# Start index 42, total length 1493
# Start index 43, total length 1493
# Start index 44, total length 1493
# Start index 45, total length 1493
# Start index 46, total length 1493
# Start index 47, total length 1493
# Start index 48, total length 1493
# Start index 49, total length 1493
# Start index 50, total length 1493
# Start index 51, total length 1493
# Start index 52, total length 1493
# Start index 53, total length 1493
# Start index 54, total length 1493
# Start index 55, total length 1493
# Start index 56, total length 1493
# Start index 57, total length 1493
# Start index 58, total length 1493
# Start index 59, total length 1493
# Start index 60, total length 1493
# Start index 61, total length 1493
# Start index 62, total length 1493
# Start index 63, total length 1493
# Start index 64, total length 1493
# Start index 65, total length 1493
# Start index 66, total length 1493
# Start index 67, total length 1493
# Start index 68, total length 1493
# Start index 69, total length 1493
# Start index 70, total length 1493
# Start index 71, total length 1493
# Start index 72, total length 1493
# Start index 73, total length 1493
# Start index 74, total length 1493
# Start index 75, total length 1493
# Start index 76, total length 1493
# Start index 77, total length 1493
# Start index 78, total length 1493
# Start index 79, total length 1493
# Start index 80, total length 1493
# Start index 81, total length 1493
# Start index 82, total length 1493
# Start index 83, total length 1493
# Start index 84, total length 1493
# Start index 85, total length 1493
# Start index 86, total length 1493
# Start index 87, total length 1493
# Start index 88, total length 1493
# Start index 89, total length 1493
# Start index 90, total length 1493
# Start index 91, total length 1493
# Start index 92, total length 1493
# Start index 93, total length 1493
# Start index 94, total length 1493
# Start index 95, total length 1493
# Start index 96, total length 1493
# Start index 97, total length 1493
# Start index 98, total length 1493
# Start index 99, total length 1493
# Start index 100, total length 1493
# Start index 101, total length 1493
# Start index 102, total length 1493
# Start index 103, total length 1493
# Start index 104, total length 1493
# Start index 105, total length 1493
# Start index 106, total length 1493
# Start index 107, total length 1493
# Start index 108, total length 1493
# Start index 109, total length 1493
# Start index 110, total length 1493
# Start index 111, total length 1493
# Start index 112, total length 1493
# Start index 113, total length 1493
# Start index 114, total length 1493
# Start index 115, total length 1493
# Start index 116, total length 1493
# Start index 117, total length 1493
# Start index 118, total length 1493
# Start index 119, total length 1493
# Start index 120, total length 1493
# Start index 121, total length 1493
# Start index 122, total length 1493
# Start index 123, total length 1493
# Start index 124, total length 1493
# Start index 125, total length 1493
# Start index 126, total length 1493
# Start index 127, total length 1493
# Start index 128, total length 1493
# Start index 129, total length 1493
# Start index 130, total length 1493
# Start index 131, total length 1493
# Start index 132, total length 1493
# Start index 133, total length 1493
# Start index 134, total length 1493
# Start index 135, total length 1493
# Start index 136, total length 1493
# Start index 137, total length 1493
# Start index 138, total length 1493
# Start index 139, total length 1493
# Start index 140, total length 1493
# Start index 141, total length 1493
# Start index 142, total length 1493
# Start index 143, total length 1493
# Start index 144, total length 1493
# Start index 145, total length 1493
# Start index 146, total length 1493
# Start index 147, total length 1493
# Start index 148, total length 1493
# Start index 149, total length 1493
# Start index 150, total length 1493
# Start index 151, total length 1493
# Start index 152, total length 1493
# Start index 153, total length 1493
# Start index 154, total length 1493
# Start index 155, total length 1493
# Start index 156, total length 1493
# Start index 157, total length 1493
# Start index 158, total length 1493
# Start index 159, total length 1493
# Start index 160, total length 1493
# Start index 161, total length 1493
# Start index 162, total length 1493
# Start index 163, total length 1493
# Start index 164, total length 1493
# Start index 165, total length 1493
# Start index 166, total length 1493
# Start index 167, total length 1493
# Start index 168, total length 1493
# Start index 169, total length 1493
# Start index 170, total length 1493
# Start index 171, total length 1493
# Start index 172, total length 1493
# Start index 173, total length 1493
# Start index 174, total length 1493
# Start index 175, total length 1493
# Start index 176, total length 1493
# Start index 177, total length 1493
# Start index 178, total length 1493
# Start index 179, total length 1493
# Start index 180, total length 1493
# Start index 181, total length 1493
# Start index 182, total length 1493
# Start index 183, total length 1493
# Start index 184, total length 1493
# Start index 185, total length 1493
# Start index 186, total length 1493
# Start index 187, total length 1493
# Start index 188, total length 1493
# Start index 189, total length 1493
# Start index 190, total length 1493
# Start index 191, total length 1493
# Start index 192, total length 1493
# Start index 193, total length 1493
# Start index 194, total length 1493
# Start index 195, total length 1493
# Start index 196, total length 1493
# Start index 197, total length 1493
# Start index 198, total length 1493
# Start index 199, total length 1493
# Start index 200, total length 1493
# Start index 201, total length 1493
# Start index 202, total length 1493
# Start index 203, total length 1493
# Start index 204, total length 1493
# Start index 205, total length 1493
# Start index 206, total length 1493
# Start index 207, total length 1493
# Start index 208, total length 1493
# Start index 209, total length 1493
# Start index 210, total length 1493
# Start index 211, total length 1493
# Start index 212, total length 1493
# Start index 213, total length 1493
# Start index 214, total length 1493
# Start index 215, total length 1493
# Start index 216, total length 1493
# Start index 217, total length 1493
# Start index 218, total length 1493
# Start index 219, total length 1493
# Start index 220, total length 1493
# Start index 221, total length 1493
# Start index 222, total length 1493
# Start index 223, total length 1493
# Start index 224, total length 1493
# Start index 225, total length 1493
# Start index 226, total length 1493
# Start index 227, total length 1493
# Start index 228, total length 1493
# Start index 229, total length 1493
# Start index 230, total length 1493
# Start index 231, total length 1493
# Start index 232, total length 1493
# Start index 233, total length 1493
# Start index 234, total length 1493
# Start index 235, total length 1493
# Start index 236, total length 1493
# Start index 237, total length 1493
# Start index 238, total length 1493
# Start index 239, total length 1493
# Start index 240, total length 1493
# Start index 241, total length 1493
# Start index 242, total length 1493
# Start index 243, total length 1493
# Start index 244, total length 1493
# Start index 245, total length 1493
# Start index 246, total length 1493
# Start index 247, total length 1493
# Start index 248, total length 1493
# Start index 249, total length 1493
# Start index 250, total length 1493
# Start index 251, total length 1493
# Start index 252, total length 1493
# Start index 253, total length 1493
# Start index 254, total length 1493
# Start index 255, total length 1493
# Start index 256, total length 1493
# Start index 257, total length 1493
# Start index 258, total length 1493
# Start index 259, total length 1493
# Start index 260, total length 1493
# Start index 261, total length 1493
# Start index 262, total length 1493
# Start index 263, total length 1493
# Start index 264, total length 1493
# Start index 265, total length 1493
# Start index 266, total length 1493
# Start index 267, total length 1493
# Start index 268, total length 1493
# Start index 269, total length 1493
# Start index 270, total length 1493
# Start index 271, total length 1493
# Start index 272, total length 1493
# Start index 273, total length 1493
# Start index 274, total length 1493
# Start index 275, total length 1493
# Start index 276, total length 1493
# Start index 277, total length 1493
# Start index 278, total length 1493
# Start index 279, total length 1493
# Start index 280, total length 1493
# Start index 281, total length 1493
# Start index 282, total length 1493
# Start index 283, total length 1493
# Start index 284, total length 1493
# Start index 285, total length 1493
# Start index 286, total length 1493
# Start index 287, total length 1493
# Start index 288, total length 1493
# Start index 289, total length 1493
# Start index 290, total length 1493
# Start index 291, total length 1493
# Start index 292, total length 1493
# Start index 293, total length 1493
# Start index 294, total length 1493
# Start index 295, total length 1493
# Start index 296, total length 1493
# Start index 297, total length 1493
# Start index 298, total length 1493
# Start index 299, total length 1493
# Start index 300, total length 1493
# Start index 301, total length 1493
# Start index 302, total length 1493
# Start index 303, total length 1493
# Start index 304, total length 1493
# Start index 305, total length 1493
# Start index 306, total length 1493
# Start index 307, total length 1493
# Start index 308, total length 1493
# Start index 309, total length 1493
# Start index 310, total length 1493
# Start index 311, total length 1493
# Start index 312, total length 1493
# Start index 313, total length 1493
# Start index 314, total length 1493
# Start index 315, total length 1493
# Start index 316, total length 1493
# Start index 317, total length 1493
# Start index 318, total length 1493
# Start index 319, total length 1493
# Start index 320, total length 1493
# Start index 321, total length 1493
# Start index 322, total length 1493
# Start index 323, total length 1493
# Start index 324, total length 1493
# Start index 325, total length 1493
# Start index 326, total length 1493
# Start index 327, total length 1493
# Start index 328, total length 1493
# Start index 329, total length 1493
# Start index 330, total length 1493
# Start index 331, total length 1493
# Start index 332, total length 1493
# Start index 333, total length 1493
# Start index 334, total length 1493
# Start index 335, total length 1493
# Start index 336, total length 1493
# Start index 337, total length 1493
# Start index 338, total length 1493
# Start index 339, total length 1493
# Start index 340, total length 1493
# Start index 341, total length 1493
# Start index 342, total length 1493
# Start index 343, total length 1493
# Start index 344, total length 1493
# Start index 345, total length 1493
# Start index 346, total length 1493
# Start index 347, total length 1493
# Start index 348, total length 1493
# Start index 349, total length 1493
# Start index 350, total length 1493
# Start index 351, total length 1493
# Start index 352, total length 1493
# Start index 353, total length 1493
# Start index 354, total length 1493
# Start index 355, total length 1493
# Start index 356, total length 1493
# Start index 357, total length 1493
# Start index 358, total length 1493
# Start index 359, total length 1493
# Start index 360, total length 1493
# Start index 361, total length 1493
# Start index 362, total length 1493
# Start index 363, total length 1493
# Start index 364, total length 1493
# Start index 365, total length 1493
# Start index 366, total length 1493
# Start index 367, total length 1493
# Start index 368, total length 1493
# Start index 369, total length 1493
# Start index 370, total length 1493
# Start index 371, total length 1493
# Start index 372, total length 1493
# Start index 373, total length 1493
# Start index 374, total length 1493
# Start index 375, total length 1493
# Start index 376, total length 1493
# Start index 377, total length 1493
# Start index 378, total length 1493
# Start index 379, total length 1493
# Start index 380, total length 1493
# Start index 381, total length 1493
# Start index 382, total length 1493
# Start index 383, total length 1493
# Start index 384, total length 1493
# Start index 385, total length 1493
# Start index 386, total length 1493
# Start index 387, total length 1493
# Start index 388, total length 1493
# Start index 389, total length 1493
# Start index 390, total length 1493
# Start index 391, total length 1493
# Start index 392, total length 1493
# Start index 393, total length 1493
# Start index 394, total length 1493
# Start index 395, total length 1493
# Start index 396, total length 1493
# Start index 397, total length 1493
# Start index 398, total length 1493
# Start index 399, total length 1493
# Start index 400, total length 1493
# Start index 401, total length 1493
# Start index 402, total length 1493
# Start index 403, total length 1493
# Start index 404, total length 1493
# Start index 405, total length 1493
# Start index 406, total length 1493
# Start index 407, total length 1493
# Start index 408, total length 1493
# Start index 409, total length 1493
# Start index 410, total length 1493
# Start index 411, total length 1493
# Start index 412, total length 1493
# Start index 413, total length 1493
# Start index 414, total length 1493
# Start index 415, total length 1493
# Start index 416, total length 1493
# Start index 417, total length 1493
# Start index 418, total length 1493
# Start index 419, total length 1493
# Start index 420, total length 1493
# Start index 421, total length 1493
# Start index 422, total length 1493
# Start index 423, total length 1493
# Start index 424, total length 1493
# Start index 425, total length 1493
# Start index 426, total length 1493
# Start index 427, total length 1493
# Start index 428, total length 1493
# Start index 429, total length 1493
# Start index 430, total length 1493
# Start index 431, total length 1493
# Start index 432, total length 1493
# Start index 433, total length 1493
# Start index 434, total length 1493
# Start index 435, total length 1493
# Start index 436, total length 1493
# Start index 437, total length 1493
# Start index 438, total length 1493
# Start index 439, total length 1493
# Start index 440, total length 1493
# Start index 441, total length 1493
# Start index 442, total length 1493
# Start index 443, total length 1493
# Start index 444, total length 1493
# Start index 445, total length 1493
# Start index 446, total length 1493
# Start index 447, total length 1493
# Start index 448, total length 1493
# Start index 449, total length 1493
# Start index 450, total length 1493
# Start index 451, total length 1493
# Start index 452, total length 1493
# Start index 453, total length 1493
# Start index 454, total length 1493
# Start index 455, total length 1493
# Start index 456, total length 1493
# Start index 457, total length 1493
# Start index 458, total length 1493
# Start index 459, total length 1493
# Start index 460, total length 1493
# Start index 461, total length 1493
# Start index 462, total length 1493
# Start index 463, total length 1493
# Start index 464, total length 1493
# Start index 465, total length 1493
# Start index 466, total length 1493
# Start index 467, total length 1493
# Start index 468, total length 1493
# Start index 469, total length 1493
# Start index 470, total length 1493
# Start index 471, total length 1493
# Start index 472, total length 1493
# Start index 473, total length 1493
# Start index 474, total length 1493
# Start index 475, total length 1493
# Start index 476, total length 1493
# Start index 477, total length 1493
# Start index 478, total length 1493
# Start index 479, total length 1493
# Start index 480, total length 1493
# Start index 481, total length 1493
# Start index 482, total length 1493
# Start index 483, total length 1493
# Start index 484, total length 1493
# Start index 485, total length 1493
# Start index 486, total length 1493
# Start index 487, total length 1493
# Start index 488, total length 1493
# Start index 489, total length 1493
# Start index 490, total length 1493
# Start index 491, total length 1493
# Start index 492, total length 1493
# Start index 493, total length 1493
# Start index 494, total length 1493
# Start index 495, total length 1493
# Start index 496, total length 1493
# Start index 497, total length 1493
# Start index 498, total length 1493
# Start index 499, total length 1493
# Start index 500, total length 1493
# Start index 501, total length 1493
# Start index 502, total length 1493
# Start index 503, total length 1493
# Start index 504, total length 1493
# Start index 505, total length 1493
# Start index 506, total length 1493
# Start index 507, total length 1493
# Start index 508, total length 1493
# Start index 509, total length 1493
# Start index 510, total length 1493
# Start index 511, total length 1493
# Start index 512, total length 1493
# Start index 513, total length 1493
# Start index 514, total length 1493
# Start index 515, total length 1493
# Start index 516, total length 1493
# Start index 517, total length 1493
# Start index 518, total length 1493
# Start index 519, total length 1493
# Start index 520, total length 1493
# Start index 521, total length 1493
# Start index 522, total length 1493
# Start index 523, total length 1493
# Start index 524, total length 1493
# Start index 525, total length 1493
# Start index 526, total length 1493
# Start index 527, total length 1493
# Start index 528, total length 1493
# Start index 529, total length 1493
# Start index 530, total length 1493
# Start index 531, total length 1493
# Start index 532, total length 1493
# Start index 533, total length 1493
# Start index 534, total length 1493
# Start index 535, total length 1493
# Start index 536, total length 1493
# Start index 537, total length 1493
# Start index 538, total length 1493
# Start index 539, total length 1493
# Start index 540, total length 1493
# Start index 541, total length 1493
# Start index 542, total length 1493
# Start index 543, total length 1493
# Start index 544, total length 1493
# Start index 545, total length 1493
# Start index 546, total length 1493
# Start index 547, total length 1493
# Start index 548, total length 1493
# Start index 549, total length 1493
# Start index 550, total length 1493
# Start index 551, total length 1493
# Start index 552, total length 1493
# Start index 553, total length 1493
# Start index 554, total length 1493
# Start index 555, total length 1493
# Start index 556, total length 1493
# Start index 557, total length 1493
# Start index 558, total length 1493
# Start index 559, total length 1493
# Start index 560, total length 1493
# Start index 561, total length 1493
# Start index 562, total length 1493
# Start index 563, total length 1493
# Start index 564, total length 1493
# Start index 565, total length 1493
# Start index 566, total length 1493
# Start index 567, total length 1493
# Start index 568, total length 1493
# Start index 569, total length 1493
# Start index 570, total length 1493
# Start index 571, total length 1493
# Start index 572, total length 1493
# Start index 573, total length 1493
# Start index 574, total length 1493
# Start index 575, total length 1493
# Start index 576, total length 1493
# Start index 577, total length 1493
# Start index 578, total length 1493
# Start index 579, total length 1493
# Start index 580, total length 1493
# Start index 581, total length 1493
# Start index 582, total length 1493
# Start index 583, total length 1493
# Start index 584, total length 1493
# Start index 585, total length 1493
# Start index 586, total length 1493
# Start index 587, total length 1493
# Start index 588, total length 1493
# Start index 589, total length 1493
# Start index 590, total length 1493
# Start index 591, total length 1493
# Start index 592, total length 1493
# Start index 593, total length 1493
# Start index 594, total length 1493
# Start index 595, total length 1493
# Start index 596, total length 1493
# Start index 597, total length 1493
# Start index 598, total length 1493
# Start index 599, total length 1493
# Start index 600, total length 1493
# Start index 601, total length 1493
# Start index 602, total length 1493
# Start index 603, total length 1493
# Start index 604, total length 1493
# Start index 605, total length 1493
# Start index 606, total length 1493
# Start index 607, total length 1493
# Start index 608, total length 1493
# Start index 609, total length 1493
# Start index 610, total length 1493
# Start index 611, total length 1493
# Start index 612, total length 1493
# Start index 613, total length 1493
# Start index 614, total length 1493
# Start index 615, total length 1493
# Start index 616, total length 1493
# Start index 617, total length 1493
# Start index 618, total length 1493
# Start index 619, total length 1493
# Start index 620, total length 1493
# Start index 621, total length 1493
# Start index 622, total length 1493
# Start index 623, total length 1493
# Start index 624, total length 1493
# Start index 625, total length 1493
# Start index 626, total length 1493
# Start index 627, total length 1493
# Start index 628, total length 1493
# Start index 629, total length 1493
# Start index 630, total length 1493
# Start index 631, total length 1493
# Start index 632, total length 1493
# Start index 633, total length 1493
# Start index 634, total length 1493
# Start index 635, total length 1493
# Start index 636, total length 1493
# Start index 637, total length 1493
# Start index 638, total length 1493
# Start index 639, total length 1493
# Start index 640, total length 1493
# Start index 641, total length 1493
# Start index 642, total length 1493
# Start index 643, total length 1493
# Start index 644, total length 1493
# Start index 645, total length 1493
# Start index 646, total length 1493
# Start index 647, total length 1493
# Start index 648, total length 1493
# Start index 649, total length 1493
# Start index 650, total length 1493
# Start index 651, total length 1493
# Start index 652, total length 1493
# Start index 653, total length 1493
# Start index 654, total length 1493
# Start index 655, total length 1493
# Start index 656, total length 1493
# Start index 657, total length 1493
# Start index 658, total length 1493
# Start index 659, total length 1493
# Start index 660, total length 1493
# Start index 661, total length 1493
# Start index 662, total length 1493
# Start index 663, total length 1493
# Start index 664, total length 1493
# Start index 665, total length 1493
# Start index 666, total length 1493
# Start index 667, total length 1493
# Start index 668, total length 1493
# Start index 669, total length 1493
# Start index 670, total length 1493
# Start index 671, total length 1493
# Start index 672, total length 1493
# Start index 673, total length 1493
# Start index 674, total length 1493
# Start index 675, total length 1493
# Start index 676, total length 1493
# Start index 677, total length 1493
# Start index 678, total length 1493
# Start index 679, total length 1493
# Start index 680, total length 1493
# Start index 681, total length 1493
# Start index 682, total length 1493
# Start index 683, total length 1493
# Start index 684, total length 1493
# Start index 685, total length 1493
# Start index 686, total length 1493
# Start index 687, total length 1493
# Start index 688, total length 1493
# Start index 689, total length 1493
# Start index 690, total length 1493
# Start index 691, total length 1493
# Start index 692, total length 1493
# Start index 693, total length 1493
# Start index 694, total length 1493
# Start index 695, total length 1493
# Start index 696, total length 1493
# Start index 697, total length 1493
# Start index 698, total length 1493
# Start index 699, total length 1493
# Start index 700, total length 1493
# Start index 701, total length 1493
# Start index 702, total length 1493
# Start index 703, total length 1493
# Start index 704, total length 1493
# Start index 705, total length 1493
# Start index 706, total length 1493
# Start index 707, total length 1493
# Start index 708, total length 1493
# Start index 709, total length 1493
# Start index 710, total length 1493
# Start index 711, total length 1493
# Start index 712, total length 1493
# Start index 713, total length 1493
# Start index 714, total length 1493
# Start index 715, total length 1493
# Start index 716, total length 1493
# Start index 717, total length 1493
# Start index 718, total length 1493
# Start index 719, total length 1493
# Start index 720, total length 1493
# Start index 721, total length 1493
# Start index 722, total length 1493
# Start index 723, total length 1493
# Start index 724, total length 1493
# Start index 725, total length 1493
# Start index 726, total length 1493
# Start index 727, total length 1493
# Start index 728, total length 1493
# Start index 729, total length 1493
# Start index 730, total length 1493
# Start index 731, total length 1493
# Start index 732, total length 1493
# Start index 733, total length 1493
# Start index 734, total length 1493
# Start index 735, total length 1493
# Start index 736, total length 1493
# Start index 737, total length 1493
# Start index 738, total length 1493
# Start index 739, total length 1493
# Start index 740, total length 1493
# Start index 741, total length 1493
# Start index 742, total length 1493
# Start index 743, total length 1493
# Start index 744, total length 1493
# Start index 745, total length 1493
# Start index 746, total length 1493
# Start index 747, total length 1493
# Start index 748, total length 1493
# Start index 749, total length 1493
# Start index 750, total length 1493
# Start index 751, total length 1493
# Start index 752, total length 1493
# Start index 753, total length 1493
# Start index 754, total length 1493
# Start index 755, total length 1493
# Start index 756, total length 1493
# Start index 757, total length 1493
# Start index 758, total length 1493
# Start index 759, total length 1493
# Start index 760, total length 1493
# Start index 761, total length 1493
# Start index 762, total length 1493
# Start index 763, total length 1493
# Start index 764, total length 1493
# Start index 765, total length 1493
# Start index 766, total length 1493
# Start index 767, total length 1493
# Start index 768, total length 1493
# Start index 769, total length 1493
# Start index 770, total length 1493
# Start index 771, total length 1493
# Start index 772, total length 1493
# Start index 773, total length 1493
# Start index 774, total length 1493
# Start index 775, total length 1493
# Start index 776, total length 1493
# Start index 777, total length 1493
# Start index 778, total length 1493
# Start index 779, total length 1493
# Start index 780, total length 1493
# Start index 781, total length 1493
# Start index 782, total length 1493
# Start index 783, total length 1493
# Start index 784, total length 1493
# Start index 785, total length 1493
# Start index 786, total length 1493
# Start index 787, total length 1493
# Start index 788, total length 1493
# Start index 789, total length 1493
# Start index 790, total length 1493
# Start index 791, total length 1493
# Start index 792, total length 1493
# Start index 793, total length 1493
# Start index 794, total length 1493
# Start index 795, total length 1493
# Start index 796, total length 1493
# Start index 797, total length 1493
# Start index 798, total length 1493
# Start index 799, total length 1493
# Start index 800, total length 1493
# Start index 801, total length 1493
# Start index 802, total length 1493
# Start index 803, total length 1493
# Start index 804, total length 1493
# Start index 805, total length 1493
# Start index 806, total length 1493
# Start index 807, total length 1493
# Start index 808, total length 1493
# Start index 809, total length 1493
# Start index 810, total length 1493
# Start index 811, total length 1493
# Start index 812, total length 1493
# Start index 813, total length 1493
# Start index 814, total length 1493
# Start index 815, total length 1493
# Start index 816, total length 1493
# Start index 817, total length 1493
# Start index 818, total length 1493
# Start index 819, total length 1493
# Start index 820, total length 1493
# Start index 821, total length 1493
# Start index 822, total length 1493
# Start index 823, total length 1493
# Start index 824, total length 1493
# Start index 825, total length 1493
# Start index 826, total length 1493
# Start index 827, total length 1493
# Start index 828, total length 1493
# Start index 829, total length 1493
# Start index 830, total length 1493
# Start index 831, total length 1493
# Start index 832, total length 1493
# Start index 833, total length 1493
# Start index 834, total length 1493
# Start index 835, total length 1493
# Start index 836, total length 1493
# Start index 837, total length 1493
# Start index 838, total length 1493
# Start index 839, total length 1493
# Start index 840, total length 1493
# Start index 841, total length 1493
# Start index 842, total length 1493
# Start index 843, total length 1493
# Start index 844, total length 1493
# Start index 845, total length 1493
# Start index 846, total length 1493
# Start index 847, total length 1493
# Start index 848, total length 1493
# Start index 849, total length 1493
# Start index 850, total length 1493
# Start index 851, total length 1493
# Start index 852, total length 1493
# Start index 853, total length 1493
# Start index 854, total length 1493
# Start index 855, total length 1493
# Start index 856, total length 1493
# Start index 857, total length 1493
# Start index 858, total length 1493
# Start index 859, total length 1493
# Start index 860, total length 1493
# Start index 861, total length 1493
# Start index 862, total length 1493
# Start index 863, total length 1493
# Start index 864, total length 1493
# Start index 865, total length 1493
# Start index 866, total length 1493
# Start index 867, total length 1493
# Start index 868, total length 1493
# Start index 869, total length 1493
# Start index 870, total length 1493
# Start index 871, total length 1493
# Start index 872, total length 1493
# Start index 873, total length 1493
# Start index 874, total length 1493
# Start index 875, total length 1493
# Start index 876, total length 1493
# Start index 877, total length 1493
# Start index 878, total length 1493
# Start index 879, total length 1493
# Start index 880, total length 1493
# Start index 881, total length 1493
# Start index 882, total length 1493
# Start index 883, total length 1493
# Start index 884, total length 1493
# Start index 885, total length 1493
# Start index 886, total length 1493
# Start index 887, total length 1493
# Start index 888, total length 1493
# Start index 889, total length 1493
# Start index 890, total length 1493
# Start index 891, total length 1493
# Start index 892, total length 1493
# Start index 893, total length 1493
# Start index 894, total length 1493
# Start index 895, total length 1493
# Start index 896, total length 1493
# Start index 897, total length 1493
# Start index 898, total length 1493
# Start index 899, total length 1493
# Start index 900, total length 1493
# Start index 901, total length 1493
# Start index 902, total length 1493
# Start index 903, total length 1493
# Start index 904, total length 1493
# Start index 905, total length 1493
# Start index 906, total length 1493
# Start index 907, total length 1493
# Start index 908, total length 1493
# Start index 909, total length 1493
# Start index 910, total length 1493
# Start index 911, total length 1493
# Start index 912, total length 1493
# Start index 913, total length 1493
# Start index 914, total length 1493
# Start index 915, total length 1493
# Start index 916, total length 1493
# Start index 917, total length 1493
# Start index 918, total length 1493
# Start index 919, total length 1493
# Start index 920, total length 1493
# Start index 921, total length 1493
# Start index 922, total length 1493
# Start index 923, total length 1493
# Start index 924, total length 1493
# Start index 925, total length 1493
# Start index 926, total length 1493
# Start index 927, total length 1493
# Start index 928, total length 1493
# Start index 929, total length 1493
# Start index 930, total length 1493
# Start index 931, total length 1493
# Start index 932, total length 1493
# Start index 933, total length 1493
# Start index 934, total length 1493
# Start index 935, total length 1493
# Start index 936, total length 1493
# Start index 937, total length 1493
# Start index 938, total length 1493
# Start index 939, total length 1493
# Start index 940, total length 1493
# Start index 941, total length 1493
# Start index 942, total length 1493
# Start index 943, total length 1493
# Start index 944, total length 1493
# Start index 945, total length 1493
# Start index 946, total length 1493
# Start index 947, total length 1493
# Start index 948, total length 1493
# Start index 949, total length 1493
# Start index 950, total length 1493
# Start index 951, total length 1493
# Start index 952, total length 1493
# Start index 953, total length 1493
# Start index 954, total length 1493
# Start index 955, total length 1493
# Start index 956, total length 1493
# Start index 957, total length 1493
# Start index 958, total length 1493
# Start index 959, total length 1493
# Start index 960, total length 1493
# Start index 961, total length 1493
# Start index 962, total length 1493
# Start index 963, total length 1493
# Start index 964, total length 1493
# Start index 965, total length 1493
# Start index 966, total length 1493
# Start index 967, total length 1493
# Start index 968, total length 1493
# Start index 969, total length 1493
# Start index 970, total length 1493
# Start index 971, total length 1493
# Start index 972, total length 1493
# Start index 973, total length 1493
# Start index 974, total length 1493
# Start index 975, total length 1493
# Start index 976, total length 1493
# Start index 977, total length 1493
# Start index 978, total length 1493
# Start index 979, total length 1493
# Start index 980, total length 1493
# Start index 981, total length 1493
# Start index 982, total length 1493
# Start index 983, total length 1493
# Start index 984, total length 1493
# Start index 985, total length 1493
# Start index 986, total length 1493
# Start index 987, total length 1493
# Start index 988, total length 1493
# Start index 989, total length 1493
# Start index 990, total length 1493
# Start index 991, total length 1493
# Start index 992, total length 1493
# Start index 993, total length 1493
# Start index 994, total length 1493
# Start index 995, total length 1493
# Start index 1428, total length 1493
# Start index 1429, total length 1493
# Start index 1430, total length 1493
# Start index 1431, total length 1493
# Start index 1432, total length 1493
# Start index 1433, total length 1493
# Start index 1434, total length 1493
# Start index 1435, total length 1493
# Start index 1436, total length 1493
# Start index 1437, total length 1493
# Start index 1438, total length 1493
# Start index 1439, total length 1493
# Start index 1440, total length 1493
# Start index 1441, total length 1493
# Start index 1442, total length 1493
# Start index 1443, total length 1493
# Start index 1444, total length 1493
# Start index 1445, total length 1493
# Start index 1446, total length 1493
# Start index 1447, total length 1493
# Start index 1448, total length 1493
# Start index 1449, total length 1493
# Start index 1450, total length 1493
# Start index 1451, total length 1493
# Start index 1452, total length 1493
# Start index 1453, total length 1493
# Start index 1454, total length 1493
# Start index 1455, total length 1493
# Start index 1456, total length 1493
# Start index 1457, total length 1493
# Start index 1458, total length 1493
# Start index 1459, total length 1493
# Start index 1460, total length 1493
# Start index 1461, total length 1493
# Start index 1462, total length 1493
# Start index 1463, total length 1493
# Start index 1464, total length 1493
# Start index 1465, total length 1493
# Start index 1466, total length 1493
# Start index 1467, total length 1493
# Start index 1468, total length 1493
# Start index 1469, total length 1493
# Start index 1470, total length 1493
# Start index 1471, total length 1493
# Start index 1472, total length 1493
# Start index 1473, total length 1493
# Start index 1474, total length 1493
# Start index 1475, total length 1493
# Start index 1476, total length 1493
# Start index 1477, total length 1493
# Start index 1478, total length 1493
# Start index 1479, total length 1493
# Start index 1480, total length 1493
# Start index 1481, total length 1493
# Start index 1482, total length 1493
# Start index 1483, total length 1493
# Start index 1484, total length 1493
# Start index 1485, total length 1493
# Start index 1486, total length 1493
# Start index 1487, total length 1493
# Start index 1488, total length 1493
# Start index 1489, total length 1493
# Start index 1490, total length 1493
# Start index 1491, total length 1493
# Start index 1492, total length 1493

# %%
with open('relevance.json', 'w', encoding='utf-8') as json_file:
    json.dump(all_dict, json_file)

# %%
all_dict[0]
# Out:
# {'mention_name': 'tuberculous pneumothorax unspecified',
#  'zero_hop_list': ['tuberculous pneumothorax'],
#  'one_hop_list': ['pneumothorax'],
#  'two_hop_list': ['spontaneous tension pneumothorax',
#   'primary spontaneous pneumothorax',
#   'hemopneumothorax',
#   'pleural disease']}

# %% [markdown]
# # load the json file and read

# %%
with open('relevance.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# %%
data['1450']['two_hop_list']
# Out:
# ['hypospadias',
#  'disease',
#  'caudal regression syndrome',
#  'partial cryptophthalmia',
#  'poland syndrome',
#  'congenital symblepharon',
#  'visceral heterotaxy',
#  'gastroschisis',
#  'renalhepaticpancreatic dysplasia',
#  'bladder exstrophyepispadiascloacal exstrophy complex',
#  'imperforate anus',
#  'developmental cardiac valvular defect',
#  'klippelfeil syndrome',
#  'congenital nervous system abnormality',
#  'orofacial cleft',
#  'omphalocele',
#  'polydactyly',
#  'radioulnar synostosis',
#  'silverrussell syndrome',
#  'neural tube defect',
#  'complete cryptophthalmia',
#  'cleft palatelateral synechia syndrome',
#  'meckels diverticulum',
#  'agnathiaotocephaly complex']
